# %%
#yolo v8 we can use it for 3 tasks-detection,segmentation,img classification
#yolov8 is a bench mark-its more faster,light weight and more accurate
#due to the absence of the gpu im using collab

# %%
# !nvidia-smi
# Out:
# Mon Nov 27 23:29:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.9/645.9 kB 9.2 MB/s eta 0:00:00
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="P5uluqx7HFjXZKM1FSF0")
project = rf.workspace("kritsakorn").project("acne-kbm0q")
dataset = project.version(21).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display,Image

# %%
# %cd /content/Acne-21
# Out:
# /content/Acne-21

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# %cd /content/Acne-21
# Out:
# /content/Acne-21

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml  weights

# %%
Image(filename="runs/detect/train2/confusion_matrix.png",width=600)

# %%
Image(filename="runs/detect/train2/F1_curve.png",width=600)

# %%
Image(filename="runs/detect/train2/results.png",width=600)

# %%
Image(filename="runs/detect/train2/PR_curve.png",width=600)

# %%
Image(filename="runs/detect/train2/P_curve.png",width=600)

# %%
Image(filename="runs/detect/train2/R_curve.png",width=600)

# %%
Image(filename="runs/detect/train2/val_batch0_pred.jpg",width=600)

# %%
#VALIDATION ON UR TEST DATA AFTER TRAINING

# %%
model=!yolo task=detect mode=val model=runs/detect/train2/weights/best.pt data=data.yaml

# %%
#INFERENCE WITH CUSTOM DATA

# %%
pwd
# Out:
# '/content/Acne-21'

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt conf=0.25 source=acne1.jpg name=acne_infer show_labels=True
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/Acne-21/acne1.jpg: 192x224 2 papuless, 3 pustuless, 104.0ms
# Speed: 1.1ms preprocess, 104.0ms inference, 110.1ms postprocess per image at shape (1, 3, 192, 224)
# Results saved to runs/detect/acne_infer
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image

# %%
Image(filename='acne1.jpg',width=640)

# %%
cd /content/Acne-21/runs/detect/acne_infer
# Out:
# /content/Acne-21/runs/detect/acne_infer

# %%
Image(filename='acne1.jpg',width=640)

# %%
cd /content/Acne-21
# Out:
# /content/Acne-21
